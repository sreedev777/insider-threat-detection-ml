# %% [markdown]
# # Day 4: Model Training and Evaluation
#
# Train a Random Forest model on the engineered features and evaluate its performance.

# %%
import sys
sys.path.append('..')
from src.train_model import load_data, train_and_evaluate

# %%
df = load_data('../data/processed/feature_table.csv')
df.head()

# %%
model, acc, prec, rec, f1 = train_and_evaluate(df, model_save_path='../models/random_forest_model.pkl')
